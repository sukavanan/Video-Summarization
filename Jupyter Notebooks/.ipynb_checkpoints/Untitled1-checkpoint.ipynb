# %%
from youtube_transcript_api import YouTubeTranscriptApi
import sys
sys.path.append('../src')
from evaluation import file_id
from functools import reduce
import json
from datetime import datetime, timedelta

# %%
def compute_end_time(start_time, duration):
    start_time = datetime.strptime(start_time, '%H:%M:%S.%f')
    duration = duration * 1000
    return start_time + timedelta(milliseconds=duration)

def secondsToStr(t):
    return "%02d:%02d:%02d.%03d" % reduce(lambda ll,b : divmod(ll[0],b) + ll[1:], [(t*1000,),1000,60,60])

# %%
transcript = YouTubeTranscriptApi.get_transcript(file_id, languages=['en'])

# %%
intermediate = []
for idx, i in enumerate(transcript):
    new_d = {}
    new_d['index'] = idx+1
    new_d['start_time'] = secondsToStr(i['start'])
    new_d['end_time'] = datetime.strftime(compute_end_time(new_d['start_time'], i['duration']), '%H:%M:%S.%f')[:-3]
    new_d['duration'] = i['duration']
    new_d['text'] = i['text']
    intermediate.append(new_d)

# %%
with open(f'../intermediate/{file_id}_parsed.json') as f:
    json.dump()
# Out:
# [{'index': 1,
#   'start_time': '00:00:04.390',
#   'end_time': '00:00:08.570',
#   'duration': 4.18,
#   'text': 'five friendly cities is a European'},
#  {'index': 2,
#   'start_time': '00:00:06.740',
#   'end_time': '00:00:10.820',
#   'duration': 4.08,
#   'text': 'project that wants to get cities cycling'},
#  {'index': 3,
#   'start_time': '00:00:08.570',
#   'end_time': '00:00:13.429',
#   'duration': 4.859,
#   'text': 'southend-on-sea and Cambridge in the UK'},
#  {'index': 4,
#   'start_time': '00:00:10.820',
#   'end_time': '00:00:15.259',
#   'duration': 4.439,
#   'text': 'middleburg and the province of Zealand'},
#  {'index': 5,
#   'start_time': '00:00:13.429',
#   'end_time': '00:00:17.390',
#   'duration': 3.961,
#   'text': 'in the Netherlands for loin in France'},
#  {'index': 6,
#   'start_time': '00:00:15.259',
#   'end_time': '00:00:19.189',
#   'duration': 3.93,
#   'text': 'and Portugal Belgium are all working'},
#  {'index': 7,
#   'start_time': '00:00:17.390',
#   'end_time': '00:00:22.310',
#   'duration': 4.92,
#   'text': 'together to promote cycling in their'},
#  {'index': 8,
#   'start_time': '00:00:19.189',
#   'end_time': '00:00:24.560',
#   'duration': 5.371,
#   'text': 'sickness in summer 2013 these cities'},
#  {'index': 9,
#   'start_time': '00:00:22.310',
#   'end_time': '00:00:26.720',
#   'duration': 4.41,
#   'text': 'held bike parade and inviting everyone'},
#  {'index': 10,
#   'start_time': '00:00:24.560',
#   'end_time': '00:00:29.470',
#   'duration': 4.91,
#   'text': 'to come along dress up and celebrate'},
#  {'index': 11,
#   'start_time': '00:00:26.720',
#   'end_time': '00:00:29.470',
#   'duration': 2.75,
#   'text': 'cycling'},
#  {'index': 12,
#   'start_time': '00:00:31.890',
#   'end_time': '00:00:37.170',
#   'duration': 5.28,
#   'text': "when I'm stayed for split and we're on"},
#  {'index': 13,
#   'start_time': '00:00:34.320',
#   'end_time': '00:00:40.320',
#   'duration': 6.0,
#   'text': 'Saturn sodomite and we like cycling'},
#  {'index': 14,
#   'start_time': '00:00:37.170',
#   'end_time': '00:00:43.020',
#   'duration': 5.85,
#   'text': "because it's a pleasure and make lots of"},
#  {'index': 15,
#   'start_time': '00:00:40.320',
#   'end_time': '00:00:46.800',
#   'duration': 6.48,
#   'text': 'new friends and have a really good time'},
#  {'index': 16,
#   'start_time': '00:00:43.020',
#   'end_time': '00:01:02.970',
#   'duration': 19.95,
#   'text': "it's good for the environment mask out"},
#  {'index': 17,
#   'start_time': '00:00:46.800',
#   'end_time': '00:01:07.920',
#   'duration': 21.12,
#   'text': 'on the bike and meet other people do you'},
#  {'index': 18,
#   'start_time': '00:01:02.970',
#   'end_time': '00:01:15.960',
#   'duration': 12.99,
#   'text': 'sigh called Bailey every day you go to'},
#  {'index': 19,
#   'start_time': '00:01:07.920',
#   'end_time': '00:01:18.390',
#   'duration': 10.47,
#   'text': "work with your boss hi I'm creditor I"},
#  {'index': 20,
#   'start_time': '00:01:15.960',
#   'end_time': '00:01:21.810',
#   'duration': 5.85,
#   'text': "love cycling because it's fun it keeps"},
#  {'index': 21,
#   'start_time': '00:01:18.390',
#   'end_time': '00:01:24.030',
#   'duration': 5.64,
#   'text': 'me fit its teeth and it keeps my carbon'},
#  {'index': 22,
#   'start_time': '00:01:21.810',
#   'end_time': '00:01:26.310',
#   'duration': 4.5,
#   'text': "footprint now I'm crash and I like"},
#  {'index': 23,
#   'start_time': '00:01:24.030',
#   'end_time': '00:01:30.530',
#   'duration': 6.5,
#   'text': "fighting because it's cheap make it"},
#  {'index': 24,
#   'start_time': '00:01:26.310',
#   'end_time': '00:01:30.530',
#   'duration': 4.22,
#   'text': 'there fast and I get keep fit'},
#  {'index': 25,
#   'start_time': '00:01:38.780',
#   'end_time': '00:01:45.750',
#   'duration': 6.97,
#   'text': 'they really have a race bicycle and some'},
#  {'index': 26,
#   'start_time': '00:01:43.920',
#   'end_time': '00:01:47.250',
#   'duration': 3.33,
#   'text': 'of the other professional side other'},
#  {'index': 27,
#   'start_time': '00:01:45.750',
#   'end_time': '00:01:50.429',
#   'duration': 4.679,
#   'text': 'ones actually I do just that for a'},
#  {'index': 28,
#   'start_time': '00:01:47.250',
#   'end_time': '00:01:53.009',
#   'duration': 5.759,
#   'text': "ledger Bobby for me actually it's also a"},
#  {'index': 29,
#   'start_time': '00:01:50.429',
#   'end_time': '00:01:55.560',
#   'duration': 5.131,
#   'text': 'matter of moving as they had also thing'},
#  {'index': 30,
#   'start_time': '00:01:53.009',
#   'end_time': '00:01:57.899',
#   'duration': 4.89,
#   'text': 'out stress actually yes and all we can'},
#  {'index': 31,
#   'start_time': '00:01:55.560',
#   'end_time': '00:01:59.610',
#   'duration': 4.05,
#   'text': 'share a lot of stress and meditate when'},
#  {'index': 32,
#   'start_time': '00:01:57.899',
#   'end_time': '00:02:05.850',
#   'duration': 7.951,
#   'text': 'the weather is a little fine like today'},
#  {'index': 33,
#   'start_time': '00:01:59.610',
#   'end_time': '00:02:08.610',
#   'duration': 9.0,
#   'text': 'is a chemical timing i live in'},
#  {'index': 34,
#   'start_time': '00:02:05.850',
#   'end_time': '00:02:13.170',
#   'duration': 7.32,
#   'text': 'connection belgium the bike is the best'},
#  {'index': 35,
#   'start_time': '00:02:08.610',
#   'end_time': '00:02:16.340',
#   'duration': 7.73,
#   'text': 'way to find our way in sydney and enough'},
#  {'index': 36,
#   'start_time': '00:02:13.170',
#   'end_time': '00:02:16.340',
#   'duration': 3.17,
#   'text': 'that inspires me as well'}]
